# %%
import pandas as pd

df=pd.read_csv("/mnt/sde1/geth/nft_analyse_v1/data/buySwap/csv/buyswap_final.csv")
df=df[df["market"]!="none"]
df["market"].value_counts()
# Out:
# OpenSea          2711
# LooksRare          71
# Rarible            63
# X2Y2               32
# Sudoswap            9
# CryptoKitties       2
# SuperRare           1
# Name: market, dtype: int64

# %%
lossDf=df[df["revenue_eth"]<0]
profitDf=df[df["revenue_eth"]>0]

print("len(df)",len(df))
print("sum(df[revenue_eth])",sum(df["revenue_eth"]))
print("sum(df[revenue_dollar])",sum(df["revenue_dollar"]))

print("len(lossDf)",len(lossDf))
print("sum(lossDf[revenue_eth])",sum(lossDf["revenue_eth"]))
print("sum(lossDf[revenue_dollar])",sum(lossDf["revenue_dollar"]))

print("len(profitDf)",len(profitDf))
print("sum(profitDf[revenue_eth])",sum(profitDf["revenue_eth"]))
print("sum(profitDf[revenue_dollar])",sum(profitDf["revenue_dollar"]))

# print("",df[ max(df[])]
# Out:
# len(df) 2889
# sum(df[revenue_eth]) 121.63380720543682
# sum(df[revenue_dollar]) 360354.7941372942
# len(lossDf) 71
# sum(lossDf[revenue_eth]) -6.774853911928949
# sum(lossDf[revenue_dollar]) -23066.31134483382
# len(profitDf) 2818
# sum(profitDf[revenue_eth]) 128.40866111736568
# sum(profitDf[revenue_dollar]) 383421.1054821277

# %%
df=pd.read_csv("/mnt/sde1/geth/nft_analyse_v1/data/buySwap/csv/buyswap_final.csv")
df=df[df["market"]=="OpenSea"]
print("OpenSea average revenue: ",sum(df["revenue_dollar"]/len(df)))

df=pd.read_csv("/mnt/sde1/geth/nft_analyse_v1/data/buySwap/csv/buyswap_final.csv")
df=df[df["market"]=="LooksRare"]
print("LooksRare average revenue: ",sum(df["revenue_dollar"]/len(df)))

df=pd.read_csv("/mnt/sde1/geth/nft_analyse_v1/data/buySwap/csv/buyswap_final.csv")
df=df[df["market"]=="Rarible"]
print("Rarible average revenue: ",sum(df["revenue_dollar"]/len(df)))

df=pd.read_csv("/mnt/sde1/geth/nft_analyse_v1/data/buySwap/csv/buyswap_final.csv")
df=df[df["market"]=="X2Y2"]
print("X2Y2 average revenue: ",sum(df["revenue_dollar"]/len(df)))

df=pd.read_csv("/mnt/sde1/geth/nft_analyse_v1/data/buySwap/csv/buyswap_final.csv")
df=df[df["market"]=="Sudoswap"]
print("Sudoswap average revenue: ",sum(df["revenue_dollar"]/len(df)))

df=pd.read_csv("/mnt/sde1/geth/nft_analyse_v1/data/buySwap/csv/buyswap_final.csv")
df=df[df["market"]=="CryptoKitties"]
print("CryptoKitties average revenue: ",sum(df["revenue_dollar"]/len(df)))

df=pd.read_csv("/mnt/sde1/geth/nft_analyse_v1/data/buySwap/csv/buyswap_final.csv")
df=df[df["market"]=="SuperRare"]
print("SuperRare average revenue: ",sum(df["revenue_dollar"]/len(df)))
# Out:
# OpenSea average revenue:  117.97062736056274
# LooksRare average revenue:  70.97856046243231
# Rarible average revenue:  543.9446305631877
# X2Y2 average revenue:  33.79406335097449
# Sudoswap average revenue:  3.9655593958675017
# CryptoKitties average revenue:  27.468718463101933
# SuperRare average revenue:  56.39634577471232

# %%
df=pd.read_csv("/mnt/sde1/geth/nft_analyse_v1/data/buySwap/csv/buyswap_final.csv")
df=df[df["market"]!="none"]
df[df["revenue_eth"]==min(df["revenue_eth"])]
# Out:
#                                         transactionHash  blockNumber  \
# 1313  0xf22d9b672e95b87d953b8f890ca2e415b2adc463da77...     14002549
#
#        timestamp  position     transactionFee    coinbase_transfer  flashbots  \
# 1313  1642148526         0  55947036489986304  1367043614527844935       True
#
#                                        toAddress  \
# 1313  0xa57bd00134b2850b2a1c55860c9e9ea100fdd6cf
#
#                                     tokenAddress  tokenId         inEth  \
# 1313  0x986aea67c7d6a15036e18678065eb663fc5be883     1648  7.212402e+21
#
#             outEth    ethPrice  revenue_eth  revenue_dollar   market
# 1313  7.213769e+21  3307.87093    -1.422991    -4707.069409  OpenSea

# %%
profitDf[profitDf["revenue_eth"]==max(profitDf["revenue_eth"])]
# Out:
#                                         transactionHash  blockNumber  \
# 1335  0x54d84a4fc0d8a01b4b996d72a6966b21b040e80d2b9a...     14016869
#
#        timestamp  position     transactionFee   coinbase_transfer  flashbots  \
# 1335  1642340578         0  57725163042820092  500000000000000000       True
#
#                                        toAddress  \
# 1335  0x000000b46a83732bda366917c4c6477eefe840d7
#
#                                     tokenAddress  tokenId         inEth  \
# 1335  0x60e4d786628fea6478f785a6d7e704777c86a7c6    10440  2.078988e+20
#
#             outEth     ethPrice  revenue_eth  revenue_dollar   market
# 1335  2.005000e+20  3354.183437     7.341061    24623.266514  OpenSea

# %%
import pandas as pd
df=pd.read_csv("/mnt/sde1/geth/nft_analyse_v1/data/buySwap/csv/buyswap_final.csv")
df=df[df["market"]!="none"]
addrMap={}
for index, row in df.iterrows():
    toAddress=row["toAddress"]
    revenue_dollar=row["revenue_dollar"]
    if toAddress not in addrMap:
        addrMap[toAddress]={"count":1,"revenue_dollar":revenue_dollar}
    else:
        addrMap[toAddress]["count"]+=1
        addrMap[toAddress]["revenue_dollar"]+=revenue_dollar
# addrMap

# %%
len(addrMap)
# Out:
# 46

# %%
addrMap["0x397ff1542f962076d0bfe58ea045ffa2d347aca0"]
# Out:
# {'count': 16, 'revenue_dollar': 32.499613695388064}

# %%
tempList=[]
for key,value in addrMap.items():
    tempList.append({"address":key,"count":value["count"]})

df = pd.DataFrame(tempList)

# %%
df.sort_values(by="count",ascending=False)
# Out:
#                                        address  count
# 2   0xef7f9d712a82ae54c6ece9d95b7e1ec7449747ed   1181
# 0   0xbf8767602970cec551c437c605f828975a4ef525    417
# 7   0x00000000c2cf7648c169b25ef1c217864bfa38cc    308
# 15  0x0b6b31b277ff5825e46e4adcc377b23ae466a48b    248
# 10  0x06a20913e78e0263f20b2591684546d50aa21a48    153
# 30  0xe7db74f559fd9e0be11a5f667c66616540878d5c     84
# 32  0x0000000009cb38fb8a1bbb8ada23c8261118f019     52
# 33  0x460441cc78340342611cfbca4c958ec50ba83d65     44
# 1   0x00000000000a93ddd65c4daa1d7160f2207842c4     44
# 3   0x000000000006b92d1ca16b6e55071e8b5626d5d6     40
# 37  0x1162ea7091f5d1784f86c9e745ea2c89296a8657     37
# 4   0xa57bd00134b2850b2a1c55860c9e9ea100fdd6cf     33
# 27  0xb21ce453533489ff7eb26cd1cef957f6485ef8ad     27
# 26  0xc26a75ce8c75aa59cccf6bc3e75df42041257fc1     27
# 42  0x52ca1cb9fc6fbd1cfe5630e74de8738b517a367a     17
# 23  0xba8f8e5c8763ac6eb7aa77ac9268e9162a686648     17
# ...

# %%
import pandas as pd
df=pd.read_csv("/mnt/sde1/geth/nft_analyse_v1/data/buySwap/csv/buyswap_final.csv")
df=df[df["market"]!="none"]
addrMap={}
for index, row in df.iterrows():
    tokenAddress=row["tokenAddress"]
    revenue_dollar=row["revenue_dollar"]
    if tokenAddress not in addrMap:
        addrMap[tokenAddress]={"count":1,"revenue_dollar":revenue_dollar}
    else:
        addrMap[tokenAddress]["count"]+=1
        addrMap[tokenAddress]["revenue_dollar"]+=revenue_dollar
        
        
tempList=[]
for key,value in addrMap.items():
    tempList.append({"address":key,"averageRevenue":value["revenue_dollar"]/value["count"]})

df = pd.DataFrame(tempList)
df.sort_values(by="averageRevenue",ascending=False)
# Out:
#                                         address  averageRevenue
# 88   0x059edd72cd353df5106d2b9cc5ab83a52287ac3a     6392.276882
# 137  0x60e4d786628fea6478f785a6d7e704777c86a7c6     5600.806775
# 39   0x7f96f68fa766d4e9b037417fe4967511152b9272      812.040001
# 57   0xba30e5f9bb24caa003e9f2f0497ad287fdf95623      762.886069
# 106  0x8a90cab2b38dba80c64b7734e58ee1db38b8992e      643.318807
# ..                                          ...             ...
# 130  0x5f9e300108fb156cfbe21c48a870876e97745af9      -15.867884
# 4    0x7c40c393dc0f283f318791d746d894ddd3693572      -18.039069
# 68   0xfbe295ad8b8f19f681c5d971cfef098b74d0fc08      -20.733046
# 188  0xcb88735a1eae17ff2a2abaec1ba03d877f4bc055      -46.890840
# 103  0x986aea67c7d6a15036e18678065eb663fc5be883     -115.318726
#
# [189 rows x 2 columns]
