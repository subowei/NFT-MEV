# %%
import pandas as pd

df=pd.read_csv("/mnt/sde1/geth/nft_analyse_v1/data/sandwichBuy/csv/sandwich_withPrice.csv")    
    
addrSet=set()
for index in range(0,len(df),3):    
    fromAddress0=df.iloc[index]["from"]
    fromAddress1=df.iloc[index+2]["from"]
    addrSet.add(fromAddress0)
    addrSet.add(fromAddress1)
    
    # if df.iloc[index+1]["nftPrice"]==0:
    #     print(df.iloc[index+1])
    
print("total from: ",len(addrSet))
print("total attack: ",len(df)/3)
# Out:
# total from:  7
# total attack:  41.0

# %%
df=pd.read_csv("/mnt/sde1/geth/nft_analyse_v1/data/sandwichBuy/csv/sandwich_withRevenue.csv")
print("total revenue: ",sum(df["revenue_dollar"]))
print("max revenue: ",max(df["revenue_dollar"]))
print("min revenue: ",min(df["revenue_dollar"]))
# Out:
# total revenue:  829474.8287913088
# max revenue:  102958.52685722087
# min revenue:  -26564.35151092387

# %%
df[df["revenue_dollar"]==max(df["revenue_dollar"])]
# Out:
#     blockNumber   timestamp  \
# 13     13816096  1639656258
#
#                                       transactionHash  bidPrice  \
# 13  0x1bc120a5f5dc268f305747b542c1b53ae896722239cc...      64.0
#
#     coinbase_transfer  nftPrice     ethPrice  revenue_eth  revenue_dollar
# 13       3.000000e+16     89.95  3972.841711    25.915587   102958.526857

# %%
df.sort_values("bidPrice")
# Out:
#     blockNumber   timestamp  \
# 2      13056183  1629382504
# 30     14907558  1654410103
# 29     14907555  1654410056
# 1      13012948  1628805719
# 0      13000672  1628641450
# 15     14003541  1642162116
# 28     14756952  1652300429
# 24     14632541  1650601725
# 14     13916211  1640995681
# 17     14025107  1642449950
# 25     14636977  1650661674
# 27     14664342  1651033354
# 16     14024059  1642436491
# 32     15246975  1659226674
# 12     13811409  1639593554
# 26     14649260  1650828019
# 33     15372301  1660925704
# 36     15390973  1661181126
# 34     15382169  1661060497
# 13     13816096  1639656258
# 31     15217979  1658836955
# 21     14302351  1646153904
# 22     14450780  1648148997
# 35     15390487  1661174869
# 23     14521046  1649095590
# 10     13752803  1638800592
# 37     15493236  1662594506
# 18     14093579  1643364993
# 11     13752957  1638802810
# 8      13550671  1636035002
# 5      13488041  1635184215
# 6      13507748  1635451295
# ...

# %%
df[df["revenue_dollar"]<0]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_927310/3301484806.py in <module>
# ----> 1 df[df["revenue_dollar"]<0]
#
# NameError: name 'df' is not defined

# %%
df=pd.read_csv("/mnt/sde1/geth/nft_analyse_v1/data/sandwichBuy/csv/punkBidEntered.csv")
df[df["punkIndex"]==2837]
# Out:
#       blockNumber                                    transactionHash  \
# 759      14781395  0x1aad3093b4f22c5311c2856a1a62f22572b52e5d25b8...
# 760      14781609  0x31380e1edef4e16dfb4eef92ad2aa1b02d649c56543b...
# 2987     14743812  0x605dced3f7e3e96b85af14387a5bd540ebddbfded8c1...
# 5127     14636650  0xe3669dcfd1a6c4091c117cc582a617f81f325ca9fe02...
# 5129     14636977  0xec3ac5f34aed1f082f481aeda553bf41d3cd69b10d29...
#
#       transactionIndex  punkIndex                                 fromAddress  \
# 759                 39       2837  0x1919db36ca2fa2e15f9000fd9cdc2edcf863e685
# 760                 25       2837  0xee698b39655285d4009a2958d62bb06bc040ef0c
# 2987                 3       2837  0x9e4dec4a9941ca7713b48c17f85f27df9a60db48
# 5127               181       2837  0xaea8e3bd369217cc6e3e6abddf0da318fba8e59b
# 5129                 0       2837  0x1919db36ca2fa2e15f9000fd9cdc2edcf863e685
#
#                      price
# 759   47500000000000000000
# ...

# %%
df=pd.read_csv("/mnt/sde1/geth/nft_analyse_v1/data/sandwichBuy/csv/punkBought.csv")
df[df["punkIndex"]==2837]
# Out:
#       blockNumber                                    transactionHash  \
# 488      14781630  0xfdb91eb3a2442f7f7a5798a9b33cc816f2aed7965375...
# 489      14781630  0xfdb91eb3a2442f7f7a5798a9b33cc816f2aed7965375...
# 2244     14743812  0x0bb96691b5b788f8164407a0fb4b3bb579d0d635b176...
# 3732     14636977  0x3326584109daa78a76d43e99f8157ee1b91a0152ec79...
#
#       transactionIndex  punkIndex                                 fromAddress  \
# 488                 67       2837  0x44a088f8567505894b50bfe626c4bc7ad6850664
# 489                 67       2837  0x0fc584529a2aefa997697fafacba5831fac0c22d
# 2244                 4       2837  0x1919db36ca2fa2e15f9000fd9cdc2edcf863e685
# 3732                 1       2837  0x0d5c661b7bc1628e6da0cabf5ba0dd7ceb1a73d6
#
#                                        toAddress price
# 488   0x0fc584529a2aefa997697fafacba5831fac0c22d     0
# 489   0x269616d549d7e8eaa82dfb17028d0b212d11232a     0
# 2244  0x0000000000000000000000000000000000000000     0
# ...

# %%
14743812
